# %%
import pandas as pd

# %%
hotel_2301 = 'Data/HOTEL_2023_01to11/Hotel_data2023/HOT2301.CSV'
hotel_2302 = 'Data/HOTEL_2023_01to11/Hotel_data2023/HOT2302.CSV'
hotel_2303 = 'Data/HOTEL_2023_01to11/Hotel_data2023/HOT2303.CSV'
hotel_2304 = 'Data/HOTEL_2023_01to11/Hotel_data2023/HOT2304.CSV'
hotel_2305 = 'Data/HOTEL_2023_01to11/Hotel_data2023/HOT2305.CSV'
hotel_2306 = 'Data/HOTEL_2023_01to11/Hotel_data2023/HOT2306.CSV'
hotel_2307 = 'Data/HOTEL_2023_01to11/Hotel_data2023/HOT2307.CSV'
hotel_2308 = 'Data/HOTEL_2023_01to11/Hotel_data2023/HOT2308.CSV'
hotel_2309 = 'Data/HOTEL_2023_01to11/Hotel_data2023/HOT2309.CSV'
hotel_2310 = 'Data/HOTEL_2023_01to11/Hotel_data2023/HOT2310.CSV'
hotel_2311 = 'Data/HOTEL_2023_01to11/Hotel_data2023/HOT2311.CSV'


file_paths_2023 = [hotel_2301, hotel_2302, hotel_2303, hotel_2304,\
              hotel_2305, hotel_2306, hotel_2307, hotel_2308,\
              hotel_2309, hotel_2310, hotel_2311]
# append data from Jan 2023 to Nov 2023
dfs = []


headers = [
    "Taxpayer_Number", "Taxpayer_Name", "Taxpayer_Address", "Taxpayer_City", "Taxpayer_State",
    "Taxpayer_Zip", "Taxpayer_County", "Taxpayer_Phone", "Location_Number", "Location_Name",
    "Location_Address", "Location_City", "Location_State", "Location_Zip", "Location_County",
    "Location_Phone", "Unit_Capacity", "Responsibility_Begin_Date_(YYYYMMDD)",
    "Responsibility_End_Date_(YYYYMMDD)", "Obligation_End_Date_(YYYYMMDD)", "Filer_Type",
    "Total_Room_Receipts", "Taxable_Receipts"
]


for file in file_paths_2023:
    try:
        df = pd.read_csv(file, names=headers, header=None, encoding='ISO-8859-1')  # or 'latin1' or 'windows-1252'
        dfs.append(df)
    except UnicodeDecodeError as e:
        print(f"Error reading {file}: {e}")

hotel_2023 = pd.concat(dfs, ignore_index=True)

# %%
# hotel_2017_path = 'Data/HOTEL2017/HOTEL2017.CSV'
# hotel_2018_path = 'Data/HOTEL2018/HOTEL18.CSV'
# hotel_2019_path = 'Data/HOTEL2019/HOTEL2019.CSV'
# hotel_2020_path = 'Data/HOTEL2020/HOTEL2020.CSV'
hotel_2021_path = 'Data/HOTEL2021/HOTEL2021.CSV'
hotel_2022_path = 'Data/HOTEL2022/HOTEL2022.CSV'

# %%
hotel_2023.dtypes
# Out:
# Taxpayer_Number                           int64
# Taxpayer_Name                            object
# Taxpayer_Address                         object
# Taxpayer_City                            object
# Taxpayer_State                           object
# Taxpayer_Zip                             object
# Taxpayer_County                           int64
# Taxpayer_Phone                           object
# Location_Number                           int64
# Location_Name                            object
# Location_Address                         object
# Location_City                            object
# Location_State                           object
# Location_Zip                              int64
# Location_County                          object
# Location_Phone                           object
# Unit_Capacity                             int64
# Responsibility_Begin_Date_(YYYYMMDD)      int64
# Responsibility_End_Date_(YYYYMMDD)       object
# Obligation_End_Date_(YYYYMMDD)            int64
# Filer_Type                                int64
# Total_Room_Receipts                     float64
# Taxable_Receipts                        float64
# dtype: object

# %%
# similar structure to append data from 2017 to 2022
# file_path_17_to_22= [hotel_2017_path, hotel_2018_path, hotel_2019_path,\
#                     hotel_2020_path, hotel_2021_path, hotel_2022_path]

# Updated has 2021 to 2023 
file_path_17_to_22= [hotel_2021_path, hotel_2022_path]


# Data type specification for zip codes as strings
dtype_spec = {'Taxpayer_Zip': str, 'Location_Zip': str}

# Function to clean zip codes
def clean_zip_code(zip_code):
    clean_zip = ''.join(filter(str.isdigit, str(zip_code)))
    return clean_zip[:5] if len(clean_zip) >= 5 else None



df1s = []

for file in file_path_17_to_22:
    try:
        # Adding low_memory=False parameter
        df = pd.read_csv(file, names=headers, header=None, encoding='ISO-8859-1', dtype=dtype_spec, low_memory=False)
        # Clean Location_Zip
        df['Location_Zip'] = df['Location_Zip'].apply(clean_zip_code)
        df = df[df['Location_Zip'].str.isnumeric()]  # Filter only numeric zips
        df1s.append(df)
    except UnicodeDecodeError as e:
        print(f"Error reading {file}: {e}")

hotel_17_to_22 = pd.concat(df1s, ignore_index=True)

# %%
hotel_17_to_22
# Out:
#         Taxpayer_Number                                      Taxpayer_Name  \
# 0           10105515737  TAN 1 ON, INC.                                ...
# 1           10105515737  TAN 1 ON, INC.                                ...
# 2           10105515737  TAN 1 ON, INC.                                ...
# 3           10105515737  TAN 1 ON, INC.                                ...
# 4           10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# ...                 ...                                                ...
# 449688      39000015964  BENNIE L MCGRIFF                              ...
# 449689      39000015964  BENNIE L MCGRIFF                              ...
# 449690      39000015964  BENNIE L MCGRIFF                              ...
# 449691      39000015964  BENNIE L MCGRIFF                              ...
# 449692      39000015964  BENNIE L MCGRIFF                              ...
#
#                                 Taxpayer_Address         Taxpayer_City  \
# 0       8504 LANDING WAY CT                       FORT WORTH
# 1       8504 LANDING WAY CT                       FORT WORTH
# 2       8504 LANDING WAY CT                       FORT WORTH
# 3       8504 LANDING WAY CT                       FORT WORTH
# 4       4610 S R L THORNTON FWY                   DALLAS
# ...                                          ...                   ...
# 449688  1011 PARVIEW CIR                          CEDAR HILL
# 449689  1011 PARVIEW CIR                          CEDAR HILL
# 449690  1011 PARVIEW CIR                          CEDAR HILL
# 449691  1011 PARVIEW CIR                          CEDAR HILL
# 449692  1011 PARVIEW CIR                          CEDAR HILL
#
#        Taxpayer_State Taxpayer_Zip  Taxpayer_County Taxpayer_Phone  \
# 0                  TX        76179              220     8174754668
# 1                  TX        76179              220     8174754668
# 2                  TX        76179              220     8174754668
# 3                  TX        76179              220     8174754668
# 4                  TX        75224               57     2143716800
# ...               ...          ...              ...            ...
# 449688             TX        75104               57     2147281677
# 449689             TX        75104               57     2147281677
# 449690             TX        75104               57     2147281677
# 449691             TX        75104               57     2147281677
# 449692             TX        75104               57     2147281677
#
#         Location_Number                                      Location_Name  \
# 0                     6  LAKEVIEW MARINA                               ...
# 1                     6  LAKEVIEW MARINA                               ...
# 2                     6  LAKEVIEW MARINA                               ...
# 3                     6  LAKEVIEW MARINA                               ...
# 4                     2  DELUXINN                                      ...
# ...                 ...                                                ...
# 449688                5  MAC'S DINER & MOTEL                           ...
# 449689                5  MAC'S DINER & MOTEL                           ...
# 449690                5  MAC'S DINER & MOTEL                           ...
# 449691                5  MAC'S DINER & MOTEL                           ...
# 449692                5  MAC'S DINER & MOTEL                           ...
#
#         ... Location_Zip Location_County Location_Phone Unit_Capacity  \
# 0       ...        76179             220                            2
# 1       ...        76179             220                            2
# 2       ...        76179             220                            2
# 3       ...        76179             220                            2
# 4       ...        75224             057                           80
# ...     ...          ...             ...            ...           ...
# 449688  ...        75144             175     9033967507            17
# 449689  ...        75144             175     9033967507            17
# 449690  ...        75144             175     9033967507            17
# 449691  ...        75144             175     9033967507            17
# 449692  ...        75144             175     9033967507            17
#
#        Responsibility_Begin_Date_(YYYYMMDD)  \
# 0                                  20200301
# 1                                  20200301
# 2                                  20200301
# 3                                  20200301
# 4                                  20100222
# ...                                     ...
# 449688                             20060601
# 449689                             20060601
# 449690                             20060601
# 449691                             20060601
# 449692                             20060601
#
#        Responsibility_End_Date_(YYYYMMDD)  Obligation_End_Date_(YYYYMMDD)  \
# 0                                                                20210331
# 1                                                                20210630
# 2                                                                20210930
# 3                                                                20211231
# 4                                                                20210131
# ...                                   ...                             ...
# 449688                                                           20220831
# 449689                                                           20220930
# 449690                                                           20221031
# 449691                                                           20221130
# 449692                                                           20221231
#
#         Filer_Type Total_Room_Receipts  Taxable_Receipts
# 0               60              100.00            100.00
# 1               60             6173.50           6173.50
# 2               60             6825.00           6825.00
# 3               60             1320.00           1320.00
# 4               50            97709.97          97709.97
# ...            ...                 ...               ...
# 449688          50                0.00              0.00
# 449689          50              360.00            360.00
# 449690          50              180.00            180.00
# 449691          50              200.00            200.00
# 449692          50              135.00            135.00
#
# [449693 rows x 23 columns]

# %%
hotel_17_to_22.dtypes
# Out:
# Taxpayer_Number                           int64
# Taxpayer_Name                            object
# Taxpayer_Address                         object
# Taxpayer_City                            object
# Taxpayer_State                           object
# Taxpayer_Zip                             object
# Taxpayer_County                           int64
# Taxpayer_Phone                           object
# Location_Number                           int64
# Location_Name                            object
# Location_Address                         object
# Location_City                            object
# Location_State                           object
# Location_Zip                             object
# Location_County                          object
# Location_Phone                           object
# Unit_Capacity                             int64
# Responsibility_Begin_Date_(YYYYMMDD)      int64
# Responsibility_End_Date_(YYYYMMDD)       object
# Obligation_End_Date_(YYYYMMDD)            int64
# Filer_Type                                int64
# Total_Room_Receipts                     float64
# Taxable_Receipts                        float64
# dtype: object

# %%
hotel_17_to_Nov23 = pd.concat([hotel_17_to_22, hotel_2023], ignore_index=True)

# %%
hotel_17_to_Nov23
# Out:
#         Taxpayer_Number                                      Taxpayer_Name  \
# 0           10105515737  TAN 1 ON, INC.                                ...
# 1           10105515737  TAN 1 ON, INC.                                ...
# 2           10105515737  TAN 1 ON, INC.                                ...
# 3           10105515737  TAN 1 ON, INC.                                ...
# 4           10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# ...                 ...                                                ...
# 669110      32092303232  KRISHNA HOTELS, L.L.C.                        ...
# 669111      32092526568  WISE HOSPITALITY LLC CA ENTITY                ...
# 669112      32092828311  JYS2017 TRUST NO 2                            ...
# 669113      39000012896  MARIA RIVERA                                  ...
# 669114      39000015964  BENNIE L MCGRIFF                              ...
#
#                                 Taxpayer_Address         Taxpayer_City  \
# 0       8504 LANDING WAY CT                       FORT WORTH
# 1       8504 LANDING WAY CT                       FORT WORTH
# 2       8504 LANDING WAY CT                       FORT WORTH
# 3       8504 LANDING WAY CT                       FORT WORTH
# 4       4610 S R L THORNTON FWY                   DALLAS
# ...                                          ...                   ...
# 669110  500 S BOYD ST                             ABERDEEN
# 669111  12924 CHARLWOOD ST                        CERRITOS
# 669112  PO BOX 3089                               GREENWOOD VILLAGE
# 669113  820 S CLOSNER BLVD APT 9                  EDINBURG
# 669114  1011 PARVIEW CIR                          CEDAR HILL
#
#        Taxpayer_State Taxpayer_Zip  Taxpayer_County Taxpayer_Phone  \
# 0                  TX        76179              220     8174754668
# 1                  TX        76179              220     8174754668
# 2                  TX        76179              220     8174754668
# 3                  TX        76179              220     8174754668
# 4                  TX        75224               57     2143716800
# ...               ...          ...              ...            ...
# 669110             SD        57401                0     6052263163
# 669111             CA        90703                0     5625999511
# 669112             CO        80155                0     3032200183
# 669113             TX        78539              108     9564097474
# 669114             TX        75104               57     2147281677
#
#         Location_Number                                      Location_Name  \
# 0                     6  LAKEVIEW MARINA                               ...
# 1                     6  LAKEVIEW MARINA                               ...
# 2                     6  LAKEVIEW MARINA                               ...
# 3                     6  LAKEVIEW MARINA                               ...
# 4                     2  DELUXINN                                      ...
# ...                 ...                                                ...
# 669110                1  HOLIDAY EXPRESS                               ...
# 669111                1  HOLIDAY INN EXPRESS                           ...
# 669112                1  125 BUD LANE                                  ...
# 669113                8  CASA MANANA MOTEL                             ...
# 669114                5  MAC'S DINER & MOTEL                           ...
#
#         ... Location_Zip Location_County Location_Phone Unit_Capacity  \
# 0       ...        76179             220                            2
# 1       ...        76179             220                            2
# 2       ...        76179             220                            2
# 3       ...        76179             220                            2
# 4       ...        75224             057                           80
# ...     ...          ...             ...            ...           ...
# 669110  ...        79015             191                           66
# 669111  ...        78520             031     9565500666            74
# 669112  ...        78639             027                            1
# 669113  ...        78539             108                           15
# 669114  ...        75144             175     9033967507            17
#
#        Responsibility_Begin_Date_(YYYYMMDD)  \
# 0                                  20200301
# 1                                  20200301
# 2                                  20200301
# 3                                  20200301
# 4                                  20100222
# ...                                     ...
# 669110                             20231024
# 669111                             20231117
# 669112                             20230901
# 669113                             20100524
# 669114                             20060601
#
#        Responsibility_End_Date_(YYYYMMDD)  Obligation_End_Date_(YYYYMMDD)  \
# 0                                                                20210331
# 1                                                                20210630
# 2                                                                20210930
# 3                                                                20211231
# 4                                                                20210131
# ...                                   ...                             ...
# 669110                                                           20231130
# 669111                                                           20231130
# 669112                                                           20231130
# 669113                                                           20231130
# 669114                                                           20231130
#
#         Filer_Type Total_Room_Receipts  Taxable_Receipts
# 0               60              100.00            100.00
# 1               60             6173.50           6173.50
# 2               60             6825.00           6825.00
# 3               60             1320.00           1320.00
# 4               50            97709.97          97709.97
# ...            ...                 ...               ...
# 669110          50           106034.62          94777.92
# 669111          50            91302.83          91302.83
# 669112          50            10024.88          10024.88
# 669113          50             2725.45           2725.45
# 669114          50              140.00            140.00
#
# [669115 rows x 23 columns]

# %%
Dallas = hotel_17_to_Nov23[hotel_17_to_Nov23['Location_City'].str.contains('DALLAS')]

# %%
Dallas
# Out:
#         Taxpayer_Number                                      Taxpayer_Name  \
# 4           10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 5           10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 6           10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 7           10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 8           10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# ...                 ...                                                ...
# 669025      32090249320  KRUPALU DEV LLC                               ...
# 669027      32090283154  LAKSHMI NARAYAN LLC                           ...
# 669046      32090718696  INDEPENDENT HOTEL LLC                         ...
# 669066      32091063589  SW HOTELS LLC                                 ...
# 669097      32091571714  CREP DALLAS HOTEL OPCO LLC                    ...
#
#                                 Taxpayer_Address         Taxpayer_City  \
# 4       4610 S R L THORNTON FWY                   DALLAS
# 5       4610 S R L THORNTON FWY                   DALLAS
# 6       4610 S R L THORNTON FWY                   DALLAS
# 7       4610 S R L THORNTON FWY                   DALLAS
# 8       4610 S R L THORNTON FWY                   DALLAS
# ...                                          ...                   ...
# 669025  1736 FORT WORTH AVE                       DALLAS
# 669027  3511 E KIEST BLVD                         DALLAS
# 669046  4220 INDEPENDENCE DR                      DALLAS
# 669066  255 MARY ANN DR                           JACKSONVILLE
# 669097  4500 HARRY HINES BLVD                     DALLAS
#
#        Taxpayer_State Taxpayer_Zip  Taxpayer_County Taxpayer_Phone  \
# 4                  TX        75224               57     2143716800
# 5                  TX        75224               57     2143716800
# 6                  TX        75224               57     2143716800
# 7                  TX        75224               57     2143716800
# 8                  TX        75224               57     2143716800
# ...               ...          ...              ...            ...
# 669025             TX        75208               57     4697894454
# 669027             TX        75203               57     2148921323
# 669046             TX        75237               57     3618164210
# 669066             OR        97530                0     6617697104
# 669097             TX        75219               57     2028351000
#
#         Location_Number                                      Location_Name  \
# 4                     2  DELUXINN                                      ...
# 5                     2  DELUXINN                                      ...
# 6                     2  DELUXINN                                      ...
# 7                     2  DELUXINN                                      ...
# 8                     2  DELUXINN                                      ...
# ...                 ...                                                ...
# 669025                1  MOTEL 6                                       ...
# 669027                1  ALL SEASONS INN AND SUITES                    ...
# 669046                1  SUPER 7                                       ...
# 669066                1  HOLIDAY INN EXPRESS & SUITES DALLAS EAST- FAIR...
# 669097                1  HOLIDAY INN DALLAS MARKET CENTER              ...
#
#         ... Location_Zip Location_County Location_Phone Unit_Capacity  \
# 4       ...        75224             057                           80
# 5       ...        75224             057                           80
# 6       ...        75224             057                           80
# 7       ...        75224             057                           80
# 8       ...        75224             057                           80
# ...     ...          ...             ...            ...           ...
# 669025  ...        75208             057                           40
# 669027  ...        75203             057                           33
# 669046  ...        75237             057                          128
# 669066  ...        75228             057                           90
# 669097  ...        75219             057                          200
#
#        Responsibility_Begin_Date_(YYYYMMDD)  \
# 4                                  20100222
# 5                                  20100222
# 6                                  20100222
# 7                                  20100222
# 8                                  20100222
# ...                                     ...
# 669025                             20230701
# 669027                             20230701
# 669046                             20230901
# 669066                             20231030
# 669097                             20231107
#
#        Responsibility_End_Date_(YYYYMMDD)  Obligation_End_Date_(YYYYMMDD)  \
# 4                                                                20210131
# 5                                                                20210228
# 6                                                                20210331
# 7                                                                20210430
# 8                                                                20210531
# ...                                   ...                             ...
# 669025                                                           20231130
# 669027                                                           20231130
# 669046                                                           20231130
# 669066                                                           20231130
# 669097                                                           20231130
#
#         Filer_Type Total_Room_Receipts  Taxable_Receipts
# 4               50            97709.97          97709.97
# 5               50            86274.08          86274.08
# 6               50           116618.01         116618.01
# 7               50           113138.11         113138.11
# 8               50           115246.34         115246.34
# ...            ...                 ...               ...
# 669025          50            50490.00          50490.00
# 669027          50            12365.00          10752.17
# 669046          50           105716.50          58074.21
# 669066          50           147765.35         132436.87
# 669097          50           160295.41         147165.05
#
# [13839 rows x 23 columns]

# %%
# Keep filtering hotel which still are in the market, delete the ones which has value in Responsibility_End_Date
# Filter the DataFrame to keep only rows where the 'Responsibility End Date (YYYYMMDD)' column is an empty string after stripping white spaces
Dallas_active_hotels = Dallas[Dallas['Responsibility_End_Date_(YYYYMMDD)'].str.strip() == '']

# Display the first few rows of the filtered DataFrame to verify the result
Dallas_active_hotels
# Out:
#         Taxpayer_Number                                      Taxpayer_Name  \
# 4           10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 5           10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 6           10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 7           10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 8           10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# ...                 ...                                                ...
# 669025      32090249320  KRUPALU DEV LLC                               ...
# 669027      32090283154  LAKSHMI NARAYAN LLC                           ...
# 669046      32090718696  INDEPENDENT HOTEL LLC                         ...
# 669066      32091063589  SW HOTELS LLC                                 ...
# 669097      32091571714  CREP DALLAS HOTEL OPCO LLC                    ...
#
#                                 Taxpayer_Address         Taxpayer_City  \
# 4       4610 S R L THORNTON FWY                   DALLAS
# 5       4610 S R L THORNTON FWY                   DALLAS
# 6       4610 S R L THORNTON FWY                   DALLAS
# 7       4610 S R L THORNTON FWY                   DALLAS
# 8       4610 S R L THORNTON FWY                   DALLAS
# ...                                          ...                   ...
# 669025  1736 FORT WORTH AVE                       DALLAS
# 669027  3511 E KIEST BLVD                         DALLAS
# 669046  4220 INDEPENDENCE DR                      DALLAS
# 669066  255 MARY ANN DR                           JACKSONVILLE
# 669097  4500 HARRY HINES BLVD                     DALLAS
#
#        Taxpayer_State Taxpayer_Zip  Taxpayer_County Taxpayer_Phone  \
# 4                  TX        75224               57     2143716800
# 5                  TX        75224               57     2143716800
# 6                  TX        75224               57     2143716800
# 7                  TX        75224               57     2143716800
# 8                  TX        75224               57     2143716800
# ...               ...          ...              ...            ...
# 669025             TX        75208               57     4697894454
# 669027             TX        75203               57     2148921323
# 669046             TX        75237               57     3618164210
# 669066             OR        97530                0     6617697104
# 669097             TX        75219               57     2028351000
#
#         Location_Number                                      Location_Name  \
# 4                     2  DELUXINN                                      ...
# 5                     2  DELUXINN                                      ...
# 6                     2  DELUXINN                                      ...
# 7                     2  DELUXINN                                      ...
# 8                     2  DELUXINN                                      ...
# ...                 ...                                                ...
# 669025                1  MOTEL 6                                       ...
# 669027                1  ALL SEASONS INN AND SUITES                    ...
# 669046                1  SUPER 7                                       ...
# 669066                1  HOLIDAY INN EXPRESS & SUITES DALLAS EAST- FAIR...
# 669097                1  HOLIDAY INN DALLAS MARKET CENTER              ...
#
#         ... Location_Zip Location_County Location_Phone Unit_Capacity  \
# 4       ...        75224             057                           80
# 5       ...        75224             057                           80
# 6       ...        75224             057                           80
# 7       ...        75224             057                           80
# 8       ...        75224             057                           80
# ...     ...          ...             ...            ...           ...
# 669025  ...        75208             057                           40
# 669027  ...        75203             057                           33
# 669046  ...        75237             057                          128
# 669066  ...        75228             057                           90
# 669097  ...        75219             057                          200
#
#        Responsibility_Begin_Date_(YYYYMMDD)  \
# 4                                  20100222
# 5                                  20100222
# 6                                  20100222
# 7                                  20100222
# 8                                  20100222
# ...                                     ...
# 669025                             20230701
# 669027                             20230701
# 669046                             20230901
# 669066                             20231030
# 669097                             20231107
#
#        Responsibility_End_Date_(YYYYMMDD)  Obligation_End_Date_(YYYYMMDD)  \
# 4                                                                20210131
# 5                                                                20210228
# 6                                                                20210331
# 7                                                                20210430
# 8                                                                20210531
# ...                                   ...                             ...
# 669025                                                           20231130
# 669027                                                           20231130
# 669046                                                           20231130
# 669066                                                           20231130
# 669097                                                           20231130
#
#         Filer_Type Total_Room_Receipts  Taxable_Receipts
# 4               50            97709.97          97709.97
# 5               50            86274.08          86274.08
# 6               50           116618.01         116618.01
# 7               50           113138.11         113138.11
# 8               50           115246.34         115246.34
# ...            ...                 ...               ...
# 669025          50            50490.00          50490.00
# 669027          50            12365.00          10752.17
# 669046          50           105716.50          58074.21
# 669066          50           147765.35         132436.87
# 669097          50           160295.41         147165.05
#
# [12348 rows x 23 columns]

# %%
Dallas = Dallas_active_hotels

# %%
unique_payer = len(set(Dallas['Taxpayer_Number']))
unique_payer
# Out:
# 419

# %%
unique_taxpayer = len(set(Dallas['Taxpayer_Number']))
print("Number of unique Taxpayer: ", unique_taxpayer)
# Out:
# Number of unique Taxpayer:  419

# %%
import csv
Dallas.to_csv("Dallas.csv", index=False, header=False)

# %%
# Drop duplicate rows based on the specified columns
unique_locations = Dallas.drop_duplicates(subset=['Location_Number', 'Location_Name', 'Location_Address','Location_County'])

# Reset the index to ensure it starts from 0
unique_locations.reset_index(drop=True, inplace=True)

# Add a new column 'Location_ID' with incremental values starting from 1
unique_locations['Location_ID'] = range(1, len(unique_locations) + 1)

# Get the number of unique locations
num_unique_locations = unique_locations.shape[0]

print("Number of unique locations:", num_unique_locations)
# Out:
# Number of unique locations: 562
# /var/folders/8m/8by7qkhx3n5fnnpb_stj_97m0000gn/T/ipykernel_16198/366523289.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_locations['Location_ID'] = range(1, len(unique_locations) + 1)

# %%
# Merge the original Dallas DataFrame with the unique_locations to include the Location_ID
Dallas_with_ID = Dallas.merge(unique_locations[['Location_Number', 'Location_Name', 'Location_Address', 'Location_County', 'Location_ID']], 
                              on=['Location_Number', 'Location_Name', 'Location_Address', 'Location_County'], 
                              how='left')

# %%
unique_ID = len(set(Dallas_with_ID['Location_ID']))
print("Number of unique Location_ID: ", unique_ID)
# Out:
# Number of unique Location_ID:  562

# %%
Dallas_with_ID
# Out:
#        Taxpayer_Number                                      Taxpayer_Name  \
# 0          10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 1          10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 2          10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3          10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 4          10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# ...                ...                                                ...
# 12343      32090249320  KRUPALU DEV LLC                               ...
# 12344      32090283154  LAKSHMI NARAYAN LLC                           ...
# 12345      32090718696  INDEPENDENT HOTEL LLC                         ...
# 12346      32091063589  SW HOTELS LLC                                 ...
# 12347      32091571714  CREP DALLAS HOTEL OPCO LLC                    ...
#
#                                Taxpayer_Address         Taxpayer_City  \
# 0      4610 S R L THORNTON FWY                   DALLAS
# 1      4610 S R L THORNTON FWY                   DALLAS
# 2      4610 S R L THORNTON FWY                   DALLAS
# 3      4610 S R L THORNTON FWY                   DALLAS
# 4      4610 S R L THORNTON FWY                   DALLAS
# ...                                         ...                   ...
# 12343  1736 FORT WORTH AVE                       DALLAS
# 12344  3511 E KIEST BLVD                         DALLAS
# 12345  4220 INDEPENDENCE DR                      DALLAS
# 12346  255 MARY ANN DR                           JACKSONVILLE
# 12347  4500 HARRY HINES BLVD                     DALLAS
#
#       Taxpayer_State Taxpayer_Zip  Taxpayer_County Taxpayer_Phone  \
# 0                 TX        75224               57     2143716800
# 1                 TX        75224               57     2143716800
# 2                 TX        75224               57     2143716800
# 3                 TX        75224               57     2143716800
# 4                 TX        75224               57     2143716800
# ...              ...          ...              ...            ...
# 12343             TX        75208               57     4697894454
# 12344             TX        75203               57     2148921323
# 12345             TX        75237               57     3618164210
# 12346             OR        97530                0     6617697104
# 12347             TX        75219               57     2028351000
#
#        Location_Number                                      Location_Name  \
# 0                    2  DELUXINN                                      ...
# 1                    2  DELUXINN                                      ...
# 2                    2  DELUXINN                                      ...
# 3                    2  DELUXINN                                      ...
# 4                    2  DELUXINN                                      ...
# ...                ...                                                ...
# 12343                1  MOTEL 6                                       ...
# 12344                1  ALL SEASONS INN AND SUITES                    ...
# 12345                1  SUPER 7                                       ...
# 12346                1  HOLIDAY INN EXPRESS & SUITES DALLAS EAST- FAIR...
# 12347                1  HOLIDAY INN DALLAS MARKET CENTER              ...
#
#        ... Location_County Location_Phone Unit_Capacity  \
# 0      ...             057                           80
# 1      ...             057                           80
# 2      ...             057                           80
# 3      ...             057                           80
# 4      ...             057                           80
# ...    ...             ...            ...           ...
# 12343  ...             057                           40
# 12344  ...             057                           33
# 12345  ...             057                          128
# 12346  ...             057                           90
# 12347  ...             057                          200
#
#       Responsibility_Begin_Date_(YYYYMMDD) Responsibility_End_Date_(YYYYMMDD)  \
# 0                                 20100222
# 1                                 20100222
# 2                                 20100222
# 3                                 20100222
# 4                                 20100222
# ...                                    ...                                ...
# 12343                             20230701
# 12344                             20230701
# 12345                             20230901
# 12346                             20231030
# 12347                             20231107
#
#       Obligation_End_Date_(YYYYMMDD)  Filer_Type  Total_Room_Receipts  \
# 0                           20210131          50             97709.97
# 1                           20210228          50             86274.08
# 2                           20210331          50            116618.01
# 3                           20210430          50            113138.11
# 4                           20210531          50            115246.34
# ...                              ...         ...                  ...
# 12343                       20231130          50             50490.00
# 12344                       20231130          50             12365.00
# 12345                       20231130          50            105716.50
# 12346                       20231130          50            147765.35
# 12347                       20231130          50            160295.41
#
#       Taxable_Receipts  Location_ID
# 0             97709.97            1
# 1             86274.08            1
# 2            116618.01            1
# 3            113138.11            1
# 4            115246.34            1
# ...                ...          ...
# 12343         50490.00          555
# 12344         10752.17          549
# 12345         58074.21          556
# 12346        132436.87          560
# 12347        147165.05          248
#
# [12348 rows x 24 columns]

# %%
# Find rows where Location_ID is missing
# Check for the case if multiple hotels are at the same location
hotels_without_id = Dallas_with_ID[Dallas_with_ID['Location_ID'].isna()]
# Check if there are any such hotels
if not hotels_without_id.empty:
    print("These hotels have no ID")
    # Optionally, you can print these rows to examine them
    print(hotels_without_id)
else:
    print("Every hotel has an ID.")
# Out:
# Every hotel has an ID.

# %%
Dallas_with_ID_sorted = Dallas_with_ID.sort_values(by=['Location_ID', 'Obligation_End_Date_(YYYYMMDD)'])
Dallas_with_ID_sorted.head(30)
# Out:
#       Taxpayer_Number                                      Taxpayer_Name  \
# 0         10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 1         10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 2         10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3         10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 4         10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 5         10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 6         10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 7         10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 8         10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 9         10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 10        10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 11        10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3485      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3486      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3487      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3488      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3489      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3490      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3491      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3492      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3493      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3494      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3495      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 3496      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 7940      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 8327      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 8713      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 9235      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 9625      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
# 9962      10105603723  OAK CLIFF HOSPITALITY, L.P.                   ...
#
#                               Taxpayer_Address         Taxpayer_City  \
# 0     4610 S R L THORNTON FWY                   DALLAS
# 1     4610 S R L THORNTON FWY                   DALLAS
# 2     4610 S R L THORNTON FWY                   DALLAS
# 3     4610 S R L THORNTON FWY                   DALLAS
# 4     4610 S R L THORNTON FWY                   DALLAS
# 5     4610 S R L THORNTON FWY                   DALLAS
# 6     4610 S R L THORNTON FWY                   DALLAS
# 7     4610 S R L THORNTON FWY                   DALLAS
# 8     4610 S R L THORNTON FWY                   DALLAS
# 9     4610 S R L THORNTON FWY                   DALLAS
# 10    4610 S R L THORNTON FWY                   DALLAS
# 11    4610 S R L THORNTON FWY                   DALLAS
# 3485  4610 S R L THORNTON FWY                   DALLAS
# 3486  4610 S R L THORNTON FWY                   DALLAS
# 3487  4610 S R L THORNTON FWY                   DALLAS
# 3488  4610 S R L THORNTON FWY                   DALLAS
# 3489  4610 S R L THORNTON FWY                   DALLAS
# 3490  4610 S R L THORNTON FWY                   DALLAS
# 3491  4610 S R L THORNTON FWY                   DALLAS
# 3492  4610 S R L THORNTON FWY                   DALLAS
# 3493  4610 S R L THORNTON FWY                   DALLAS
# 3494  4610 S R L THORNTON FWY                   DALLAS
# 3495  4610 S R L THORNTON FWY                   DALLAS
# 3496  4610 S R L THORNTON FWY                   DALLAS
# 7940  4610 S R L THORNTON FWY                   DALLAS
# 8327  4610 S R L THORNTON FWY                   DALLAS
# 8713  4610 S R L THORNTON FWY                   DALLAS
# 9235  4610 S R L THORNTON FWY                   DALLAS
# 9625  4610 S R L THORNTON FWY                   DALLAS
# 9962  4610 S R L THORNTON FWY                   DALLAS
#
#      Taxpayer_State Taxpayer_Zip  Taxpayer_County Taxpayer_Phone  \
# 0                TX        75224               57     2143716800
# 1                TX        75224               57     2143716800
# 2                TX        75224               57     2143716800
# 3                TX        75224               57     2143716800
# 4                TX        75224               57     2143716800
# 5                TX        75224               57     2143716800
# 6                TX        75224               57     2143716800
# 7                TX        75224               57     2143716800
# 8                TX        75224               57     2143716800
# 9                TX        75224               57     2143716800
# 10               TX        75224               57     2143716800
# 11               TX        75224               57     2143716800
# 3485             TX        75224               57     2143716800
# 3486             TX        75224               57     2143716800
# 3487             TX        75224               57     2143716800
# 3488             TX        75224               57     2143716800
# 3489             TX        75224               57     2143716800
# 3490             TX        75224               57     2143716800
# 3491             TX        75224               57     2143716800
# 3492             TX        75224               57     2143716800
# 3493             TX        75224               57     2143716800
# 3494             TX        75224               57     2143716800
# 3495             TX        75224               57     2143716800
# 3496             TX        75224               57     2143716800
# 7940             TX        75224               57     2143716800
# 8327             TX        75224               57     2143716800
# 8713             TX        75224               57     2143716800
# 9235             TX        75224               57     2143716800
# 9625             TX        75224               57     2143716800
# 9962             TX        75224               57     2143716800
#
#       Location_Number                                      Location_Name  ...  \
# 0                   2  DELUXINN                                      ...  ...
# 1                   2  DELUXINN                                      ...  ...
# 2                   2  DELUXINN                                      ...  ...
# 3                   2  DELUXINN                                      ...  ...
# 4                   2  DELUXINN                                      ...  ...
# 5                   2  DELUXINN                                      ...  ...
# 6                   2  DELUXINN                                      ...  ...
# 7                   2  DELUXINN                                      ...  ...
# 8                   2  DELUXINN                                      ...  ...
# 9                   2  DELUXINN                                      ...  ...
# 10                  2  DELUXINN                                      ...  ...
# 11                  2  DELUXINN                                      ...  ...
# 3485                2  DELUXINN                                      ...  ...
# 3486                2  DELUXINN                                      ...  ...
# 3487                2  DELUXINN                                      ...  ...
# 3488                2  DELUXINN                                      ...  ...
# 3489                2  DELUXINN                                      ...  ...
# 3490                2  DELUXINN                                      ...  ...
# 3491                2  DELUXINN                                      ...  ...
# 3492                2  DELUXINN                                      ...  ...
# 3493                2  DELUXINN                                      ...  ...
# 3494                2  DELUXINN                                      ...  ...
# 3495                2  DELUXINN                                      ...  ...
# 3496                2  DELUXINN                                      ...  ...
# 7940                2  DELUXINN                                      ...  ...
# 8327                2  DELUXINN                                      ...  ...
# 8713                2  DELUXINN                                      ...  ...
# 9235                2  DELUXINN                                      ...  ...
# 9625                2  DELUXINN                                      ...  ...
# 9962                2  DELUXINN                                      ...  ...
#
#      Location_County Location_Phone Unit_Capacity  \
# 0                057                           80
# 1                057                           80
# 2                057                           80
# 3                057                           80
# 4                057                           80
# 5                057                           80
# 6                057                           80
# 7                057                           80
# 8                057                           80
# 9                057                           80
# 10               057                           80
# 11               057                           80
# 3485             057                           80
# 3486             057                           80
# 3487             057                           80
# 3488             057                           80
# 3489             057                           80
# 3490             057                           80
# 3491             057                           80
# 3492             057                           80
# 3493             057                           80
# 3494             057                           80
# 3495             057                           80
# 3496             057                           80
# 7940             057                           80
# 8327             057                           80
# 8713             057                           80
# 9235             057                           80
# 9625             057                           80
# 9962             057                           80
#
#      Responsibility_Begin_Date_(YYYYMMDD) Responsibility_End_Date_(YYYYMMDD)  \
# 0                                20100222
# 1                                20100222
# 2                                20100222
# 3                                20100222
# 4                                20100222
# 5                                20100222
# 6                                20100222
# 7                                20100222
# 8                                20100222
# 9                                20100222
# 10                               20100222
# 11                               20100222
# 3485                             20100222
# 3486                             20100222
# 3487                             20100222
# 3488                             20100222
# 3489                             20100222
# 3490                             20100222
# 3491                             20100222
# 3492                             20100222
# 3493                             20100222
# 3494                             20100222
# 3495                             20100222
# 3496                             20100222
# 7940                             20100222
# 8327                             20100222
# 8713                             20100222
# 9235                             20100222
# 9625                             20100222
# 9962                             20100222
#
#      Obligation_End_Date_(YYYYMMDD)  Filer_Type  Total_Room_Receipts  \
# 0                          20210131          50             97709.97
# 1                          20210228          50             86274.08
# 2                          20210331          50            116618.01
# 3                          20210430          50            113138.11
# 4                          20210531          50            115246.34
# 5                          20210630          50            104191.35
# 6                          20210731          50            119418.26
# 7                          20210831          50             96114.58
# 8                          20210930          50             91479.71
# 9                          20211031          50            107150.37
# 10                         20211130          50             90597.71
# 11                         20211231          50             93138.19
# 3485                       20220131          50             87278.98
# 3486                       20220228          50             81508.42
# 3487                       20220331          50             96534.56
# 3488                       20220430          50            105661.66
# 3489                       20220531          50            103091.01
# 3490                       20220630          50            105310.20
# 3491                       20220731          50            109607.69
# 3492                       20220831          50             97915.33
# 3493                       20220930          50            103359.99
# 3494                       20221031          50            106828.47
# 3495                       20221130          50             98716.44
# 3496                       20221231          50            106098.76
# 7940                       20230131          50             92907.99
# 8327                       20230228          50             91995.16
# 8713                       20230331          50            103634.09
# 9235                       20230430          50            118655.42
# 9625                       20230531          50            115578.13
# 9962                       20230630          50            113206.33
#
#      Taxable_Receipts  Location_ID
# 0            97709.97            1
# 1            86274.08            1
# 2           116618.01            1
# 3           113138.11            1
# 4           115246.34            1
# 5           104191.35            1
# 6           119418.26            1
# 7            96114.58            1
# 8            91479.71            1
# 9           107150.37            1
# 10           90597.71            1
# 11           93138.19            1
# 3485         87278.98            1
# 3486         81508.42            1
# 3487         96534.56            1
# 3488        105661.66            1
# 3489        103091.01            1
# 3490        105310.20            1
# 3491        109607.69            1
# 3492         97915.33            1
# 3493        103359.99            1
# 3494        106828.47            1
# 3495         98716.44            1
# 3496        106098.76            1
# 7940         92907.99            1
# 8327         91995.16            1
# 8713        103634.09            1
# 9235        118655.42            1
# 9625        115578.13            1
# 9962        113206.33            1
#
# [30 rows x 24 columns]

# %%
Dallas_with_ID_sorted.to_csv("Dallas_with_ID.csv",index=False, header=False)
